# %%
import pandas as pd

# %%
stops = pd.read_csv('stops.txt')

# %%
print(stops.columns)
# Out:
# Index(['stop_id', 'stop_name', 'stop_desc', 'stop_lat', 'stop_lon',
#        'location_type', 'platform_code', 'parent_station', 'level_id'],
#       dtype='object')

# %%
stops.head(50)
# Out:
#      stop_id            stop_name                             stop_desc  \
# 0       7168          1 Decembrie                 Str. Victoriei, Ilfov
# 1       7685          1 Decembrie                 Str. Victoriei, Ilfov
# 2   PV1_5393          1 Decembrie                                   NaN
# 3   PV1_5394          1 Decembrie                                   NaN
# 4   PV2_5395          1 Decembrie                                   NaN
# 5   PV2_5396          1 Decembrie                                   NaN
# 6      14739     1 Decembrie 1918                                   NaN
# 7       8667     1 Decembrie 1918                        DJ 601A, Ilfov
# 8       8670     1 Decembrie 1918                        DJ 601A, Ilfov
# 9   PV1_5142     1 Decembrie 1918                                   NaN
# 10  PV1_5143     1 Decembrie 1918                                   NaN
# 11  PV1_5153     1 Decembrie 1918                                   NaN
# ...

# %%
stops[['stop_lat', 'stop_lon']].duplicated().sum()
# Out:
# np.int64(166)
